# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Setting the style for seaborn
sns.set(style="whitegrid")
# Load the Iris dataset
df = sns.load_dataset('iris')

# ... (rest of your code remains unchanged)

plt.figure(figsize=(10, 6))
# Calculate correlation matrix only for numeric columns
numeric_df = df.select_dtypes(include=['float', 'int'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# Insight
print("The heatmap shows strong correlations between petal length and petal width, and between sepal length and petal length.")
# Out:
# The heatmap shows strong correlations between petal length and petal width, and between sepal length and petal length.
